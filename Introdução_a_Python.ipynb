# %% [markdown]
# <a href="https://colab.research.google.com/github/lanlanzz/Portfolio/blob/main/Introdu%C3%A7%C3%A3o_a_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Aula 1

# %%
print("I Competição de Programção da Start")
# Out:
# I Competição de Programção da Start

# %%
ano = "II"

print (ano, "Competição de Programção da Start")
# Out:
# II Competição de Programção da Start

# %%
print(f"{ano} Competição de Programção da Start ")
# Out:
# II Competição de Programção da Start

# %% [markdown]
# ## Aula 2

# %%
livro_ficcao = 8
livro_n_ficcao = 10
livro_infantil = 6

pontos_rodrigo = livro_ficcao + livro_n_ficcao + livro_infantil

print(pontos_rodrigo)
# Out:
# 24

# %% [markdown]
# Aula 3

# %%
 total_de_figurinhas = int(input("Digite o total de figurinhas: "))
 numero_de_amigos = int(input("Digite o número de amigos: "))

 figurinhas_amigos = total_de_figurinhas // (numero_de_amigos + 2)
 figurinhas_joao = 2 * figurinhas_amigos

 print("João recebeu", figurinhas_joao, "figurinhas")

# %% [markdown]
# Aula 4

# %%
numero_de_alunos = int(input("Digite a quantidade de alunos: "))
numero_de_monitores = int(input("Digite a quantidade de monitores: "))
resposta_positiva = "sim, pode ir"
resposta_negativa = "não pode ir"

if numero_de_alunos + numero_de_monitores <= 50:
    print(resposta_positiva)
else:
    print(resposta_negativa)

# %% [markdown]
# Aula 5

# %%
P = int(input("Digite a posição da portinha P (0 ou 1): "))
R = int(input("Digite a posição da portinha R (0 ou 1): "))

if P == 0:
    print("C")
elif P == 1 and R == 1:
    print("A")
elif P == 1 and R == 0:
    print("B")

# %% [markdown]
# Aula 6

# %%
def calcula_idade_maior(idade_monica, idade_filho1, idade_filho2):
      idade_filho3 = idade_monica - idade_filho1 - idade_filho2

      idade_maxima = max(idade_filho1, idade_filho2, idade_filho3)

      return idade_filho3, idade_maxima

calcula_idade_maior(68, 12, 30)

# %% [markdown]
# Aula 7

# %%
# Entrada = numero inteiro (2)
#Saída = 2 x 1 = 2

def calcula_tabuada(número):
 for i in range(1, 11):
  print(f"{número} x {i} = {número * i}")


calcula_tabuada(23)

# %% [markdown]
# Aula 8

# %%
idade_monica = 40
idade_filho1 = 12
idade_filho2 = 15
idade_filho3 = idade_monica - (idade_filho1 + idade_filho2)

idades = [idade_filho1, idade_filho2, idade_filho3]
mais_velho = max(idades)

print(f"O filho mais velho tem {mais_velho} anos.")

# %% [markdown]
# Aula 9

# %% [markdown]
# Escreva um programa que peça ao usuário para digitar um número inteiro e informe se ele é par ou ímpar.

# %%
# Solicita um número do usuário
numero = int(input("Digite um número inteiro: "))

# Verifica se é par ou ímpar
if numero % 2 == 0:
    print(f"O número {numero} é par.")
else:
    print(f"O número {numero} é ímpar.")
